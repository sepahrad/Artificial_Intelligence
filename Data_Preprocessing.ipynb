# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[np.nan, 3, np.nan, 1],
                   [2, 3, np.nan, 1],
                   [np.nan, np.nan, np.nan, 4],
                   [np.nan, 3, np.nan, 5],
                   [np.nan, 1, np.nan, np.nan],
                   [np.nan, np.nan, np.nan, np.nan]], columns=list('ABCD'))
df
# Out:
#      A    B   C    D
# 0  NaN  3.0 NaN  1.0
# 1  2.0  3.0 NaN  1.0
# 2  NaN  NaN NaN  4.0
# 3  NaN  3.0 NaN  5.0
# 4  NaN  1.0 NaN  NaN
# 5  NaN  NaN NaN  NaN

# %%
df.isnull()
# Out:
#        A      B     C      D
# 0   True  False  True  False
# 1  False  False  True  False
# 2   True   True  True  False
# 3   True  False  True  False
# 4   True  False  True   True
# 5   True   True  True   True

# %%
df.isnull().sum() #Number of miss values per column
# Out:
# A    5
# B    2
# C    6
# D    2
# dtype: int64

# %%
df.isna() # Equals to df.isnull()
# Out:
#        A      B     C      D
# 0   True  False  True  False
# 1  False  False  True  False
# 2   True   True  True  False
# 3   True  False  True  False
# 4   True  False  True   True
# 5   True   True  True   True

# %%
df
# Out:
#      A    B   C    D
# 0  NaN  3.0 NaN  1.0
# 1  2.0  3.0 NaN  1.0
# 2  NaN  NaN NaN  4.0
# 3  NaN  3.0 NaN  5.0
# 4  NaN  1.0 NaN  NaN
# 5  NaN  NaN NaN  NaN

# %%
pd.isna(df['A'])
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# Name: A, dtype: bool

# %%
df['A'].notna()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# Name: A, dtype: bool

# %%
df.fillna(0) #Fill per column
# Out:
#      A    B    C    D
# 0  0.0  3.0  0.0  1.0
# 1  2.0  3.0  0.0  1.0
# 2  0.0  0.0  0.0  4.0
# 3  0.0  3.0  0.0  5.0
# 4  0.0  1.0  0.0  0.0
# 5  0.0  0.0  0.0  0.0

# %%
df.fillna(df.mean())
# Out:
#      A    B   C     D
# 0  2.0  3.0 NaN  1.00
# 1  2.0  3.0 NaN  1.00
# 2  2.0  2.5 NaN  4.00
# 3  2.0  3.0 NaN  5.00
# 4  2.0  1.0 NaN  2.75
# 5  2.0  2.5 NaN  2.75

# %%
df.fillna(df.mean()['A':'B'])
# Out:
#      A    B   C    D
# 0  2.0  3.0 NaN  1.0
# 1  2.0  3.0 NaN  1.0
# 2  2.0  2.5 NaN  4.0
# 3  2.0  3.0 NaN  5.0
# 4  2.0  1.0 NaN  NaN
# 5  2.0  2.5 NaN  NaN

# %%
df
# Out:
#      A    B   C    D
# 0  NaN  3.0 NaN  1.0
# 1  2.0  3.0 NaN  1.0
# 2  NaN  NaN NaN  4.0
# 3  NaN  3.0 NaN  5.0
# 4  NaN  1.0 NaN  NaN
# 5  NaN  NaN NaN  NaN

# %%
#df.fillna(method='ffill')
df.ffill()
# Out:
#      A    B   C    D
# 0  NaN  3.0 NaN  1.0
# 1  2.0  3.0 NaN  1.0
# 2  2.0  3.0 NaN  4.0
# 3  2.0  3.0 NaN  5.0
# 4  2.0  1.0 NaN  5.0
# 5  2.0  1.0 NaN  5.0

# %%
df
# Out:
#      A    B   C    D
# 0  NaN  3.0 NaN  1.0
# 1  2.0  3.0 NaN  1.0
# 2  NaN  NaN NaN  4.0
# 3  NaN  3.0 NaN  5.0
# 4  NaN  1.0 NaN  NaN
# 5  NaN  NaN NaN  NaN

# %%
df.fillna(value = {'A': 0, 'B': 1, 'C': 2, 'D': 3}, limit=1)
# Out:
#      A    B    C    D
# 0  0.0  3.0  2.0  1.0
# 1  2.0  3.0  NaN  1.0
# 2  NaN  1.0  NaN  4.0
# 3  NaN  3.0  NaN  5.0
# 4  NaN  1.0  NaN  3.0
# 5  NaN  NaN  NaN  NaN

# %%
df.fillna(value = {'A': 0, 'B': 1, 'C': 2, 'D': 3})
# Out:
#      A    B    C    D
# 0  0.0  3.0  2.0  1.0
# 1  2.0  3.0  2.0  1.0
# 2  0.0  1.0  2.0  4.0
# 3  0.0  3.0  2.0  5.0
# 4  0.0  1.0  2.0  3.0
# 5  0.0  1.0  2.0  3.0

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df.dropna(axis=0)
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5]

# %%
df['A'].dropna()
# Out:
# 1    2.0
# Name: A, dtype: float64

# %%
df
# Out:
#      A    B   C    D
# 0  NaN  3.0 NaN  1.0
# 1  2.0  3.0 NaN  1.0
# 2  NaN  NaN NaN  4.0
# 3  NaN  3.0 NaN  5.0
# 4  NaN  1.0 NaN  NaN
# 5  NaN  NaN NaN  NaN

# %%
df.dropna(thresh = 2) #Drop rows with more than 2 NaN
# Out:
#      A    B   C    D
# 0  NaN  3.0 NaN  1.0
# 1  2.0  3.0 NaN  1.0
# 3  NaN  3.0 NaN  5.0

# %%
df
# Out:
#      A    B   C    D
# 0  NaN  3.0 NaN  1.0
# 1  2.0  3.0 NaN  1.0
# 2  NaN  NaN NaN  4.0
# 3  NaN  3.0 NaN  5.0
# 4  NaN  1.0 NaN  NaN
# 5  NaN  NaN NaN  NaN

# %%
df.dropna(how='all') # Drop rows that all their columns are NaN
# Out:
#      A    B   C    D
# 0  NaN  3.0 NaN  1.0
# 1  2.0  3.0 NaN  1.0
# 2  NaN  NaN NaN  4.0
# 3  NaN  3.0 NaN  5.0
# 4  NaN  1.0 NaN  NaN

# %%
df.dropna(subset=['B']) # Drop rows where NaN appear in specific column
# Out:
#      A    B   C    D
# 0  NaN  3.0 NaN  1.0
# 1  2.0  3.0 NaN  1.0
# 3  NaN  3.0 NaN  5.0
# 4  NaN  1.0 NaN  NaN

# %%
from sklearn.preprocessing import MinMaxScaler
